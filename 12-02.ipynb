# %% [markdown]
# # Data

# %%
products = [
    (101, "Mobile", "Electronics", 20000),
    (102, "Laptop", "Electronics", 55000),
    (103, "Shoes", "Fashion", 3000),
    (104, "Watch", "Fashion", 2500),
    (105, "Headphones", "Electronics", 1500)
]

purchases = [
    ("User1", 101, 1),
    ("User2", 103, 2),
    ("User1", 101, 1),
    ("User1", 101, 1),
    ("User1", 101, 1),
]

searches = ["Mobile", "Shoes", "Mobile", "Laptop", "Mobile", "Watch"
]

# %% [markdown]
# ### Prodname list

# %%
prod_names = []
for i in range (0, len(products)): 
    prod_names.append(products[i][2])
prod_names
# Out:
# ['Electronics', 'Electronics', 'Fashion', 'Fashion', 'Electronics']

# %% [markdown]
# ### Costliest Prod Code

# %%
cp = products[0][3]

for i in range(len(products)):
    if products[i][3] > cp:
        cp = products[i][3]

print(cp)
# Out:
# 55000

# %%
# prod_cat = []
# for i in range(len(products)):
#     if products[i][2] == prod_cat:
#         prod
